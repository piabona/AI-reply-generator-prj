# %% [markdown]
# # 데이터im

# %%
import pandas as pd

yogiyo = pd.read_csv('yogiyo_reviews_0908.csv')

# %%
idx = [10, 17, 27, 1002, 1009, 1023, 10001, 10249, 11993, 11986]

yogiyo[['고객리뷰','사장댓글']]

pd.DataFrame(yogiyo[['고객리뷰','사장댓글']], index=idx)
# Out:
#                                                     고객리뷰  \
# 10                             맛있습니다! 근데 국물이 안와서 아쉽습니다..
# 17       돼지고기찌개에 돼지고기가 없는 마법...\n리뷰테러는 안할껀데 이건 선 넘은듯요.,.
# 27                                        제육 도시락 늘 맛있네요.
# 1002        감사히 잘먹었습니다~! \n양념은 맵찔찔찔찔이인 제가 먹기엔 쪼오금 매웠어여ㅎㅎ
# 1009                                          앗잇어요ㅋㅋㅋ드세용
# 1023                         국밥 땡길땐 무조건 여기서 시켜요 한번 드셔보세요
# 10001  고기가 진짜 맛있어요\n비위 약해서 돼지고기 원래 잘 못먹는데\n이건 무슨 고기가 달아요
# 10249                   진짜 최고에염 앞으로 곱창은 여기서만 먹을거에용\n❤❤❤❤
# 11993  예상보다 배달이 빨랐네요\n평소 쫄면 좋아하는데..오늘은 냉 쫄면~  시원하고 개운...
# 11986  맛있어요. 쫄면도 맛있고 김밥도 맛있어요. 근데 자성당은 무슨 뜻인가요? 자꾸 볼때...
#
#                                                     사장댓글
# 10     안녕하세요 1988응답하라추억의옛날도시락입니다.\n\n저희 측 실수로 인하여 누락이...
# 17     안녕하세요 ha**님. 상세한 리뷰 주셔서 감사합니다.\n\n주신 내용 잘 읽었습니...
# 27     맛있게 드셨다니 감사드립니다! a0**님의 리뷰를 보니 힘이 솟아나요.\n\n항상 ...
# 1002   우선 주문과 리뷰작성\n너무너무 감사드립니다🙏 즐거운 식사되셨나요?!! 리뷰 남겨주...
# ...

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 48.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 31.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 101.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.7 MB/s eta 0:00:00
# ...

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer, AutoTokenizer, AutoModel, AutoModelForCausalLM

# AutoModelForCausalLM.from_pretrained(f"{DATA_PATH}0919_youth_gpt").to(device)


# "skt/kogpt2-base-v2" 모델과 토크나이저 불러오기
model_name = "skt/kogpt2-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# 문장 생성 함수 정의
def generate_sentence(prompt, max_length, repetition_penalty, use_cache,do_sample, temperature, top_k, num_return_sequences=1, ):
    input_ids = tokenizer.encode(prompt, return_tensors="pt")

    # 모델에 입력하여 문장 생성
    output_ids = model.generate(input_ids,
                                max_length=max_length,
                                num_return_sequences=num_return_sequences,
                                pad_token_id=tokenizer.eos_token_id)

    # 생성된 문장 디코딩
    generated_sentences = [tokenizer.decode(output, skip_special_tokens=True) for output in output_ids]
    return generated_sentences

# 문장 생성 예제
prompt = "너무 맛있어요!!"
generated_sentences = generate_sentence(prompt,
                                        max_length=1024,
                                        repetition_penalty=2.0,
                                        use_cache=True,
                                        do_sample=True,
                                        temperature=0.8,
                                        top_k=10,
                                        num_return_sequences=1
                                        )
# 생성된 문장 출력
for sentence in generated_sentences:
    print("Generated Sentence: ", sentence)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Generated Sentence:  너무 맛있어요!!!
# #먹스타그램 #맛스타그램 #먹방 #먹짤 #위꼴 #위꼴사 #인스타푸드 #푸드스타그램 #좋아요
# #팔로우 #맞팔 #선팔 #instafood #foodporn #foodgasm #foodinsta #foodpics #foodpicslike #like4like #foodpics #foodpicslikeforfollow #likeforfollow #likeforfollowme #likeforfollow #likeforfollow4follow #likeforfollow4follow #likeforfollow4follow #likeforfollow4follow #likeforfollow4follow #...

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer, AutoTokenizer, AutoModel, AutoModelForCausalLM

# AutoModelForCausalLM.from_pretrained(f"{DATA_PATH}0919_youth_gpt").to(device)


# "skt/kogpt2-base-v2" 모델과 토크나이저 불러오기
model_name = "skt/kogpt2-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# 문장 생성 함수 정의
def generate_sentence(prompt, max_length=100, num_return_sequences=1):
    input_ids = tokenizer.encode(prompt, return_tensors="pt")

    # 모델에 입력하여 문장 생성
    output_ids = model.generate(input_ids,
                                max_length=max_length,
                                num_return_sequences=num_return_sequences,
                                pad_token_id=tokenizer.eos_token_id)

    # 생성된 문장 디코딩
    generated_sentences = [tokenizer.decode(output, skip_special_tokens=True) for output in output_ids]
    return generated_sentences
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer, AutoTokenizer, AutoModel, AutoModelForCausalLM

# AutoModelForCausalLM.from_pretrained(f"{DATA_PATH}0919_youth_gpt").to(device)


# "skt/kogpt2-base-v2" 모델과 토크나이저 불러오기
model_name = "skt/kogpt2-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# 문장 생성 함수 정의
def generate_sentence(prompt, max_length=100, num_return_sequences=1):
    input_ids = tokenizer.encode(prompt, return_tensors="pt")

    # 모델에 입력하여 문장 생성
    output_ids = model.generate(input_ids,
                                max_length=max_length,
                                num_return_sequences=num_return_sequences,
                                pad_token_id=tokenizer.eos_token_id)

    # 생성된 문장 디코딩
    generated_sentences = [tokenizer.decode(output, skip_special_tokens=True) for output in output_ids]
    return generated_sentences

# 문장 생성 예제
prompt = "맛은 있는데 너무 짜요..."
generated_sentences = generate_sentence(prompt, max_length=150, num_return_sequences=1)

# 생성된 문장 출력
for sentence in generated_sentences:
    print("Review : ", prompt)
    print("Reply : ", sentence)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Review :  맛은 있는데 너무 짜요...
# Reply :  맛은 있는데 너무 짜요....
# 이거 진짜 맛있네요 ᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏ

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer, AutoTokenizer, AutoModel, AutoModelForCausalLM

# AutoModelForCausalLM.from_pretrained(f"{DATA_PATH}0919_youth_gpt").to(device)


# "skt/kogpt2-base-v2" 모델과 토크나이저 불러오기
model_name = "skt/kogpt2-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# 문장 생성 함수 정의
def generate_sentence(prompt, max_length=100, num_return_sequences=1):
    input_ids = tokenizer.encode(prompt, return_tensors="pt")

    # 모델에 입력하여 문장 생성
    output_ids = model.generate(input_ids,
                                max_length=max_length,
                                num_return_sequences=num_return_sequences,
                                pad_token_id=tokenizer.eos_token_id)

    # 생성된 문장 디코딩
    generated_sentences = [tokenizer.decode(output, skip_special_tokens=True) for output in output_ids]
    return generated_sentences

# 문장 생성 예제
prompt = "양이 적고 맛도 별로... 다른데 시키는게 나을듯"
generated_sentences = generate_sentence(prompt, max_length=150, num_return_sequences=1)

# 생성된 문장 출력
for sentence in generated_sentences:
    print("Review : ", prompt)
    print("Reply : ", sentence)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Review :  양이 적고 맛도 별로... 다른데 시키는게 나을듯
# Reply :  양이 적고 맛도 별로... 다른데 시키는게 나을듯. #20180712 #미롱_식단
# 저녁 : #닭가슴살 #닭가슴살샐러드
# 저녁 : #닭가슴살샐러드
# 저녁 : #닭가슴살샐러드
# 저녁 : #닭가슴살샐러드
# 저녁 : #닭가슴살샐러드
# 저녁 : #닭가슴살샐러드
# 저녁 : #닭가슴살샐러드
# 저녁 : #닭가슴살샐러드
# 저녁 : #닭가슴살샐러드
# 저녁 :

# %%
import pandas as pd

pn = pd.read_csv('posneg_train_37000.csv')

# %%
pn
# Out:
#                                                   review  sentiment     score
# 0                              맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요          1  0.566494
# 1                             기름 있는 부분이 생각보다 많아요! 참고하세요           0  0.723872
# 2        양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!          1  0.608408
# 3                                                    .,.          0  0.499478
# 4      냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...          1  0.381793
# ...                                                  ...        ...       ...
# 37135  맛있어요 저번에주문하고 맛있어서또주문핰건데 늦은시간에시켜서그렄지 국물이 엄청 걸쭉하...          1  0.424215
# 37136                                         맛있어요 또시킬게요          1  0.720691
# 37137                           정말 맛있게 잘먹었어요!자주 시켜 먹을께요!          1  0.833007
# 37138  와우. 여기뭐죠 주변에서 맛있다고 먹어보라해서 시켰는데 육수가 일단 시원칼칼하니 조...          1  0.900031
# 37139  제발 양파추가 선택란 하나 만들어주세요. 단무지대신 양파달라고 요청써놨지만 바쁠때 ...          1  0.431002
#
# [37140 rows x 3 columns]

# %%
pn['sentiment'].value_counts()
# Out:
# 1    35316
# 0     1824
# Name: sentiment, dtype: int64

# %%
35316/(35316+1824)
# Out:
# 0.9508885298869144

# %%
gpt = pd.read_csv('gpt_short_ver_3000_fin.csv')

# %%
gpt[['original_review','gpt_review','gpt_reply']]
# Out:
#                                         original_review  \
# 0               맛도 양도 모두 만족합니다 배달도 정확히 보내 주시고 아주 만족합니다.
# 1                              너무 배고파서 먹다가 찍었어요. 너무맛있어요
# 2     두번째시켜요~ 이번엔 아이들이 잡채가 먹고싶대서 주문해봤는데 고기도 많이 들어가있고...
# 3                                         푸짐하고 너무 맛있어용~
# 4                                반찬 한가지 한가지가 다 찐으로 맛있어요
# ...                                                 ...
# 3001                                    배달도빠르고 맛도최고입니다~
# 3002                                양 많고 맛있고 가성비 짱이에요 b
# 3003  저 여기선 처음 시켜봤어요. 맛있네요 이렇게 맛있는 닭을 이제야 먹어보다니~ 종종 ...
# 3004     항상시켜먹지만 너무 맛있고 푸짐하고 좋아요. 다음에 또 시켜먹을게요! 잘먹었습니다
# 3005              너무 맛있고 양도 많아서 배부르게잘먹었습니다. 다음에도 또시킬게요.
#
#                                              gpt_review  \
# 0          김치찌개는 별로였어요. 약간 김치국 느낌이 나서 실망했어요. 고기도 별로였고.
# 1          음식이 너무 싱겁고 부족해서 맛이 없었어요. 배달도 늦게 왔고 실망스러웠어요.
# 2                 잡채는 짜다고 하지도 않았는데 맛이 진짜 짜요. 먹기 어려웠어요.
# 3                  가격에 비해 음식의 양도 적고 맛도 별로였어요. 실망이었습니다.
# ...

# %%
idx = [3, 247, 3002, 2726, 3005, 2731, 2732, 2741]

pd.DataFrame(gpt[['original_review','gpt_review','gpt_reply']], index=idx)
# Out:
#                                        original_review  \
# 3                                        푸짐하고 너무 맛있어용~
# 247             맛있어서 재주문 또 했어요 배달도 빠르고 포장도 잘되있고 양도 많아요
# 3002                               양 많고 맛있고 가성비 짱이에요 b
# 2726                           고기는 항상 여기서 시켜먹어요 짱짱맛 bb
# 3005             너무 맛있고 양도 많아서 배부르게잘먹었습니다. 다음에도 또시킬게요.
# 2731                        처음시켜봤는데 진짜 맛있어요 목살 왤케 부드러워
# 2732                        진짜 정말정말 맛있습니다 고기는 여기서만 시켜요
# 2741  여기 맛 퀄리티 모두 훌륭하네요 주문요청사항도 잘 챙겨주시고 대단히 만족하며 먹었습니다
#
#                                              gpt_review  \
# 3                  가격에 비해 음식의 양도 적고 맛도 별로였어요. 실망이었습니다.
# 247   맛있어서 재주문했다고 해서 기대하고 시켰는데 실망이에요. 다맛있지 않아요. 실망이에요.
# 3002           양이 부족하고 맛도 별로였어요. 가성비도 그렇게 좋지 않은 것 같아요.
# 2726                               고기가 삶아서 그런지 맛이 없어요.
# 3005  맛이 아쉬웠어요. 양념이 부족하고 치킨 자체의 맛도 그냥 그랬어요. 다음에는 다른 ...
# 2731       목살은 뭔가 살짝 쓴 맛이 나서 별로였어요. 다른 메뉴가 더 맛있을 거 같아요
# 2732   고기는 진짜 싱겁고 맛이 없었어요. 왜 이렇게 많이 칭칭거리는 건지 이해가 안 가네요
# ...

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification",
                      model="MoritzLaurer/mDeBERTa-v3-base-mnli-xnli")

sequence = "Angela Merkel is a politician in Germany and the president of CDU"
labels = ["politics", "economy", "entertainment", "environment"]
output = classifier(sequence, labels, multi_label=False)
print(output)
